# %% [markdown]
# # Problem Definition

# %% [markdown]
# > In South Korea, most of people tend to open a shop, restaurant, cafe and etc after they retire. However, it is not easy to make it successful because there are already a lot of venues like that.
#
# > Many people who got retired are facing difficulties with deciding where to open and what kind of shop to do. To try to figure out this problem, it will be very helpful to analyze cities of South Korea and then cluster regions of same feature. For example, it is possible to divide regions by most common venues. Finally it will give stakeholders insight about openning a restaurant.
#
# > I will use population of korea data below and get venues information from Foursquare API. And I will figure out what kind of venues is most popular in each city.

# %%
import types
import pandas as pd
from botocore.client import Config
import ibm_boto3

# %%
# The code was removed by Watson Studio for sharing.
# Out:
# Index(['Unnamed: 0', 'admin_region', 'admin_city', 'total(m^2)', 'city(m^2)',
#        'no_city(m^2)', 'address_compo_short_name', 'formatted_addres_name',
#        'geo_location_lat', 'geo_location_lng', 'viewport_north_lat',
#        'viewport_north_lng', 'viewport_south_lat', 'viewport_south_lng',
#        'bounds_north_lat', 'bounds_north_lng', 'bounds_south_lat',
#        'bounds_south_lng', 'area', 'population', 'man', 'woman'],
#       dtype='object')

# %%
df.head()
# Out:
#    Unnamed: 0 admin_region admin_city    total(m^2)     city(m^2)  \
# 0           0           전국         전국  1.003637e+11  2.582576e+10
# 1           1        서울특별시      서울특별시  6.052428e+08  6.052428e+08
# 2           2        부산광역시      부산광역시  7.700357e+08  6.803294e+08
# 3           3        대구광역시      대구광역시  8.836031e+08  5.651572e+08
# 4           4        인천광역시      인천광역시  1.063115e+09  5.037525e+08
#
#    no_city(m^2) address_compo_short_name formatted_addres_name  \
# 0  7.453796e+10                      NaN                   NaN
# 1           NaN                    Seoul                 Seoul
# 2  8.970627e+07                    Busan                 Busan
# 3  3.184459e+08                    Daegu                 Daegu
# 4  5.593628e+08                  Incheon               Incheon
#
#    geo_location_lat  geo_location_lng  ...  viewport_south_lat  \
# 0               NaN               NaN  ...                 NaN
# ...

# %%
# !conda install -c conda-forge folium=0.5.0 --yes
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2019.6.16          |           py36_1         149 KB  conda-forge
#     altair-3.2.0               |           py36_0         770 KB  conda-forge
#     openssl-1.1.1c             |       h516909a_0         2.1 MB  conda-forge
#     branca-0.3.1               |             py_0          25 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     ca-certificates-2019.6.16  |       hecc5488_0         145 KB  conda-forge
#     ------------------------------------------------------------
# ...

# %%
import folium

# %%
Korea_map = folium.Map(location=[36, 127.14], zoom_start=7)

for lat, lon, poi,in zip(df['geo_location_lat'], df['geo_location_lng'], df['admin_city']):
    try:
        label = folium.Popup(str(poi), parse_html=True)
        folium.CircleMarker(
            [lat, lon],
            radius=5,
            popup=label,
            fill=True,
            fill_opacity=0.7).add_to(Korea_map)
    except:
            print()
Korea_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
